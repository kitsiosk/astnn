# %%
import pandas as pd

# %%
f1 = 'data/java/bcb_funcs_all.tsv'
data = pd.read_csv(f1, delimiter='\t')

# %%
data.columns = ['id', 'code']

# %%
data
# Out:
#              id                                               code
# 0           661      public void convert(File src, File dest) t...
# 1          1362      public static int[] bubbleSort(int... a) {...
# 2          1363      public static int[] bubbleSortOtimizado(in...
# 3          2450      public void process(String dir) {\n       ...
# 4          6937      public static void main(String[] args) thr...
# ...         ...                                                ...
# 59612  23653940      JarAgletClassLoader(URL codebase, Certific...
# 59613  23655348      public boolean fileCompare(String from, St...
# 59614  23672349      public static byte[] calculateMD4(byte[] d...
# 59615  23672350      public static byte[] calculateMD5(byte[] d...
# 59616  23672354      public static byte[] calculateSHA1(byte[] ...
#
# [59617 rows x 2 columns]

# %%
f2 = 'data/java/bcb_pair_ids.pkl'
data_pairs = pd.read_pickle(f2)

# %%
data_pairs
# Out:
#             id1       id2 label
# 0       3024986   3024993     2
# 1        308643    727183     1
# 2        308643    587124     1
# 3        308643    481939     1
# 4        210006    308643     1
# ...         ...       ...   ...
# 97530  20502118  23677111     0
# 97531   1468160  23677115     0
# 97532   8232818  23677118     0
# 97533     98304  23677118     0
# 97534  22503546  23677112     0
#
# [97535 rows x 3 columns]

# %%
d = pd.read_pickle('/Users/konstantinos/Desktop/Clone Generalization/binary files/bcb_1vsAll/data_pairs_all_2000.pickle')

# %%
d
# Out:
#                                                    code1  \
# 0      public void run () {\n    try {\n        int i...
# 1      public static void doVersionCheck (View view) ...
# 2      public boolean import_pieces (String filename)...
# 3      public static BufferedReader getUserSolveStrea...
# 4      public static void doVersionCheck (View view) ...
# ...                                                  ...
# 37071  void close (HashMap moreInfo) throws IOExcepti...
# 37072  public void createPdf (String filename) throws...
# 37073  public void run () {\n    IStructuredSelection...
# 37074  private void initComponents () {\n    java.awt...
# 37075  private void reader (JarFile jar_file, String ...
#
#                                                    code2  label  \
# 0      public void loadSourceCode () {\n    int lengt...      1
# 1      public static void doVersionCheck (View view) ...      1
# 2      public static String get (String strUrl) {\n  ...      1
# 3      private static String getDocumentAt (String ur...      1
# 4      private String getFanFouMessage (int pageNo) t...      1
# ...                                                  ...    ...
# 37071  public static void main (String [] args) {\n  ...      0
# 37072  public static void main (String [] args) {\n  ...      0
# 37073  public static void main (String [] args) {\n  ...      0
# 37074  public static void main (String [] args) {\n  ...      0
# 37075  public static void main (String [] args) {\n  ...      0
#
#        functionality_id
# 0                     2
# 1                     2
# 2                     2
# 3                     2
# 4                     2
# ...                 ...
# 37071                45
# 37072                45
# 37073                45
# 37074                45
# 37075                45
#
# [37076 rows x 4 columns]

# %%
f_all = pd.concat([d['code1'], d['code2']]).unique()

# %%
map = {}
for i,f in enumerate(f_all):
    map[f] = i

# %%
id1 = []
id2 = []
for i in range(len(d)):
    id1.append(map[d['code1'].iloc[i]])
    id2.append(map[d['code2'].iloc[i]])

# %%
f_ids = pd.DataFrame({'id1':id1, 'id2':id2, 'label':d['label'], 'functionality_id':d['functionality_id']})

# %%
f_ids
# Out:
#          id1    id2  label  functionality_id
# 0          0     18      1                 2
# 1          1      7      1                 2
# 2          2     25      1                 2
# 3          3     11      1                 2
# 4          1     24      1                 2
# ...      ...    ...    ...               ...
# 37071  14587  17786      0                45
# 37072  14588  17786      0                45
# 37073  14589  17786      0                45
# 37074  14590  17786      0                45
# 37075   5385  17786      0                45
#
# [37076 rows x 4 columns]

# %%
f_ids.to_pickle('/Users/konstantinos/Desktop/Clone Generalization/binary files/bcb_1vsAll_ASTNN/bcb_pair_ids_1vsRest.pickle')

# %%
id = []
code = []
for (k,v) in map.items():
    id.append(v)
    code.append(k)

# %%
data_all_df = pd.DataFrame({'id':id, 'code':code})

# %%
data_all_df.to_pickle('/Users/konstantinos/Desktop/Clone Generalization/binary files/bcb_1vsAll_ASTNN/bcb_funcs_all_1vsRest.pickle')
